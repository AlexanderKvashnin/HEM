# %%
# !pip install numpy==1.26.4
# !pip install pandas==2.0.3
# !pip install ase==3.22.1
# !pip install -i https://test.pypi.org/simple/ sandor

import os
from ase.io import write
from sandor.functions import get_sandwich_structures

# %%
# Paths to files.
path_solid = os.path.join('structure_examples', 'solid.xyz')
path_liquid = os.path.join('structure_examples', 'liquid.xyz')

# %%
# Generate sandwich structures.
sandwich_structures = get_sandwich_structures(path_solid, path_liquid)
print(len(sandwich_structures))

# Saving sandwich_structures
path = 'sandwich_structures.xyz'
write(path, sandwich_structures)
# Out:
# 10
